# %% [markdown]
# <a href="https://colab.research.google.com/github/Jomonjoseph25/DSA_B5_Assignments/blob/main/Case_Study_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Reading Data Set**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
Cars_Data=pd.read_csv('/content/drive/MyDrive/Assignment2/cars_data.csv')
Cars_Data
# Out:
#          Make        Model    Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 0      Suzuki       Vitara  Philippine  ...              0.13     200.9       11.5
# 1       Honda        S2000      Henrik  ...              0.02     158.5        8.8
# 2         BMW           Z4      Lebbie  ...              0.24     149.5       14.4
# 3      Toyota       Tacoma    Jefferey  ...              0.20     153.3       11.5
# 4        Ford      Festiva     Glendon  ...              0.18     122.0       14.9
# ...       ...          ...         ...  ...               ...       ...        ...
# 9995    Mazda      Tribute      Cooper  ...              0.14     245.8        8.0
# 9996      GMC  Sierra 2500         Dud  ...              0.11     147.4       12.3
# 9997  Mercury      Mariner     Chariot  ...              0.12     198.1       11.8
# 9998   Daewoo      Leganza       Dynah  ...              0.04     206.7       12.2
# ...

# %% [markdown]
# **Check For Null Value**

# %%
Cars_Data.isna().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# **Male vs Female**

# %%
d = Cars_Data["Buyer Gender"].value_counts()
d.plot(kind='bar')

# %% [markdown]
# **Top 5 Cars Based on Sale Price**

# %%
Sale_Price=Cars_Data.nlargest(5,'Sale Price','first')
Sale_Price
# Out:
#             Make      Model   Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 5984  Volkswagen  Jetta III    Rachael  ...              0.06     204.9       12.6
# 1270        Audi         A6      Thorn  ...              0.16     171.3       13.0
# 3460       Lexus         LX      Aldin  ...              0.12     193.7        4.5
# 9032       Mazda       MX-6  Sylvester  ...              0.15     232.0        3.9
# 302        Lexus         ES       Brig  ...              0.21     228.1        4.7
#
# [5 rows x 20 columns]

# %% [markdown]
# **Least 5 Cars Based on Resell Price**

# %%
Resell_Price=Cars_Data.nsmallest(5,'Resell Price','first')
Resell_Price
# Out:
#             Make        Model Nickname  ... 5-yr Depreciation Top Speed  0-60 Time
# 2446   Chevrolet         1500  Corenda  ...              0.25     239.6       11.2
# 4933         GMC  Savana 1500     Lark  ...              0.01     158.7        9.0
# 566       Jaguar           XF   Payton  ...              0.19     249.3        6.9
# 2538  Mitsubishi       3000GT     Thia  ...              0.14     222.0       10.3
# 5869    Infiniti          G37    Sonny  ...              0.04     131.6       12.3
#
# [5 rows x 20 columns]
